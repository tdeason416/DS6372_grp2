# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style('darkgrid')

import scipy
import statsmodels
import statsmodels.api as sm
from statsmodels.formula.api import ols

import scipy.stats as stats
import matplotlib.pyplot as plt
import math

import os
# Out:
# /Users/vanessatorres/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
print(os.listdir("../vanessatorres/desktop/kickstarter-projects"))
# Out:
# ['.DS_Store', '.ipynb_checkpoints', '.Rapp.history', 'KS', 'ks-projects-201612.csv', 'ks-projects-201801.csv']

# %%
df_ks16 = pd.read_csv("../vanessatorres/desktop/kickstarter-projects/ks-projects-201612.csv", encoding='ISO-8859-14')
# Out:
# /Users/vanessatorres/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_ks16.drop(['Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16'], axis=1, inplace=True)

# %%
cols = df_ks16.columns.tolist()
for entry in np.arange(0,len(cols),1):
    cols[entry] = cols[entry].rstrip()
df_ks16.columns = cols
df_ks16.columns

df_ks16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 323750 entries, 0 to 323749
# Data columns (total 13 columns):
# ID               323750 non-null int64
# name             323748 non-null object
# category         323745 non-null object
# main_category    323750 non-null object
# currency         323750 non-null object
# deadline         323750 non-null object
# goal             323750 non-null object
# launched         323750 non-null object
# pledged          323750 non-null object
# state            323750 non-null object
# backers          323750 non-null object
# country          323750 non-null object
# usd pledged      319960 non-null object
# dtypes: int64(1), object(12)
# memory usage: 32.1+ MB

# %%
df_ks18 = pd.read_csv("../vanessatorres/desktop/kickstarter-projects/ks-projects-201801.csv", encoding='ISO-8859-14')

# %%
df_ks18.drop(['usd_pledged_real', 'usd_goal_real'], axis=1, inplace=True)

# %%
df_ks18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378661 entries, 0 to 378660
# Data columns (total 13 columns):
# ID               378661 non-null int64
# name             378657 non-null object
# category         378661 non-null object
# main_category    378661 non-null object
# currency         378661 non-null object
# deadline         378661 non-null object
# goal             378661 non-null float64
# launched         378661 non-null object
# pledged          378661 non-null float64
# state            378661 non-null object
# backers          378661 non-null int64
# country          378661 non-null object
# usd pledged      374864 non-null float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 37.6+ MB

# %%
df_ks = pd.concat([df_ks16, df_ks18])

# %%
df_ks[['goal', 'pledged', 'usd pledged', 'backers']] = df_ks[['goal', 'pledged', 'usd pledged', 'backers']].apply(pd.to_numeric, errors='coerce')
df_ks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 702411 entries, 0 to 378660
# Data columns (total 13 columns):
# ID               702411 non-null int64
# name             702405 non-null object
# category         702406 non-null object
# main_category    702411 non-null object
# currency         702411 non-null object
# deadline         702411 non-null object
# goal             701779 non-null float64
# launched         702411 non-null object
# pledged          701787 non-null float64
# state            702411 non-null object
# backers          701788 non-null float64
# country          702411 non-null object
# usd pledged      694201 non-null float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 75.0+ MB

# %%
df_ks['state'].value_counts() < 100
states = ['failed', 'successful', 'live', 'undefined', 'suspended']

# %%
df_ks = df_ks[df_ks['state'].isin(states)]

# %%
percentual_success = round(df_ks["state"].value_counts() / len(df_ks["state"]) * 100,2)

print("State Percentual in %:")
print(percentual_success)

plt.figure(figsize=(12,6))
sns.countplot(x='state', data=df_ks)

axl = sns.countplot(x="state", data=df_ks)
axl.set_xticklabels(axl.get_xticklabels(),rotation=45)
axl.set_title("Status Project Distribution", fontsize=15)
axl.set_xlabel("State Description", fontsize=12)
axl.set_ylabel("Count", fontsize=12)

plt.show()
# Out:
# State Percentual in %:
# failed        58.03
# successful    39.17
# live           1.15
# undefined      1.13
# suspended      0.53
# Name: state, dtype: float64

# %%
df_ks.isnull().sum()
# Out:
# ID                  0
# name                6
# category            5
# main_category       0
# currency            0
# deadline            0
# goal              632
# launched            0
# pledged           624
# state               0
# backers           623
# country             0
# usd pledged      8210
# dtype: int64

# %%
df_ks = df_ks.drop(df_ks[df_ks['name'].isnull() == True].index)

# %%
df_ks = df_ks.drop(df_ks[df_ks['goal'].isnull() == True].index)

# %%
df_ks = df_ks.drop(df_ks[df_ks['pledged'].isnull() == True].index)

# %%
df_ks = df_ks.drop(df_ks[df_ks['backers'].isnull() == True].index)

# %%
df_ks = df_ks.drop(df_ks[df_ks['usd pledged'].isnull() == True].index)

# %%
df_ks.isnull().sum()
# Out:
# ID               0
# name             0
# category         0
# main_category    0
# currency         0
# deadline         0
# goal             0
# launched         0
# pledged          0
# state            0
# backers          0
# country          0
# usd pledged      0
# dtype: int64

# %%
df_ks.describe()
# Out:
#                  ID          goal       pledged        backers   usd pledged
# count  6.169360e+05  6.169360e+05  6.169360e+05  616936.000000  6.169360e+05
# mean   1.074400e+09  4.422993e+04  1.007747e+04     114.096157  8.034540e+03
# std    6.190220e+08  1.123862e+06  9.779999e+04     975.215361  8.526672e+04
# min    5.971000e+03  1.000000e-02  0.000000e+00       0.000000  0.000000e+00
# 25%    5.378556e+08  2.000000e+03  4.700000e+01       2.000000  2.700000e+01
# 50%    1.074278e+09  5.000000e+03  7.630000e+02      15.000000  5.595496e+02
# 75%    1.609944e+09  1.500000e+04  4.525000e+03      62.000000  3.646230e+03
# max    2.147476e+09  1.000000e+08  2.033899e+07  219382.000000  2.033899e+07

# %%
#Nulls removed
percentual_success = round(df_ks["state"].value_counts() / len(df_ks["state"]) * 100,2)

print("State Percentual in %:")
print(percentual_success)

plt.figure(figsize=(12,6))
sns.countplot(x='state', data=df_ks)

axl = sns.countplot(x="state", data=df_ks)
axl.set_xticklabels(axl.get_xticklabels(),rotation=45)
axl.set_title("Status Project Distribution", fontsize=15)
axl.set_xlabel("State Description", fontsize=12)
axl.set_ylabel("Count", fontsize=12)

plt.show()
# Out:
# State Percentual in %:
# failed        58.69
# successful    39.62
# live           1.16
# suspended      0.53
# Name: state, dtype: float64

# %%
plt.figure(figsize=(16,6))
sns.countplot(x='main_category', data=df_ks, hue='state')
plt.legend(loc='upper center')
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>

# %%
plt.figure(figsize=(16,6))
sns.countplot(x='country', data=df_ks, hue='state')
plt.legend(loc='upper center')
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>

# %%
df_ks_lm = ols('goal ~ main_category', data=df_ks).fit()
print(sm.stats.anova_lm(df_ks_lm, type=2))
# Out:
#                      df        sum_sq       mean_sq          F        PR(>F)
# main_category      14.0  5.465488e+14  3.903920e+13  30.929282  1.485560e-83
# Residual       616921.0  7.786829e+17  1.262208e+12        NaN           NaN
# /Users/vanessatorres/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/vanessatorres/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Users/vanessatorres/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
df_ks_lm = ols('goal ~ country', data=df_ks).fit()
print(sm.stats.anova_lm(df_ks_lm, type=2))
# Out:
#                 df        sum_sq       mean_sq          F        PR(>F)
# country       21.0  5.264423e+14  2.506868e+13  19.860229  2.893119e-75
# Residual  616914.0  7.787030e+17  1.262255e+12        NaN           NaN
# /Users/vanessatorres/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/vanessatorres/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Users/vanessatorres/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
groupby_country = df_ks.groupby('country')
for country, value in groupby_country['goal']:
    print((country, value.mean()))
# Out:
# ('AT', 38380.289570552144)
# ('AU', 73042.00224364302)
# ('BE', 33015.90202702703)
# ('CA', 57894.41988681581)
# ('CH', 301247.82844036695)
# ('DE', 60644.21552321552)
# ('DK', 141628.78255602665)
# ('ES', 47307.51240734773)
# ('FR', 86152.97439544808)
# ('GB', 26905.18102005134)
# ('HK', 187972.08910891088)
# ('IE', 43790.364478114476)
# ('IT', 71396.36575481256)
# ('JP', 1298777.1875)
# ('LU', 26508.252631578947)
# ('MX', 257329.2781341108)
# ('NL', 64567.174370709385)
# ('NO', 291690.3056894889)
# ('NZ', 34241.417539267015)
# ('SE', 306986.33917015605)
# ('SG', 21172.415254237287)
# ('US', 40110.518132227386)

# %%
groupby_country = df_ks.groupby('main_category')
for country, value in groupby_country['goal']:
    print((country, value.mean()))
# Out:
# ('Art', 37447.22000063073)
# ('Comics', 22241.9599024773)
# ('Crafts', 11077.036253143337)
# ('Dance', 8803.813234859674)
# ('Design', 43189.23427741908)
# ('Fashion', 24354.45921414102)
# ('Film & Video', 74558.0921960361)
# ('Food', 48898.48107700514)
# ('Games', 42918.250236594584)
# ('Journalism', 99855.26700488054)
# ('Music', 14953.97644944571)
# ('Photography', 11581.00266304348)
# ('Publishing', 21657.645604587837)
# ('Technology', 113185.31963549313)
# ('Theater', 22292.310445948027)

# %%
np.random.seed()
countries = ["AT","AU","BE","CA","CH","DE","DK","ES","FR","GB","HK","IE","IT","LU","MX","NL","NO","NZ","SE","SG","US"]

#Generate random data
active_country = np.random.choice(a= countries,
                                  p=[0.047, 0.047, 0.047, 0.047, 0.047, 0.047, 0.047, 0.047, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048],
                                  size=1000)

active_pledged = stats.poisson.rvs(loc=18,
                                   mu=30,
                                   size=1000)

active_frame = pd.DataFrame({"countries":active_country,"amounts":active_pledged})
groups = active_frame.groupby("countries").groups

#Extract individual countries
AT = active_pledged[groups["AT"]]
AU = active_pledged[groups["AU"]]
BE = active_pledged[groups["BE"]]
CA = active_pledged[groups["CA"]]
CH = active_pledged[groups["CH"]]
DE = active_pledged[groups["DE"]]
DK = active_pledged[groups["DK"]]
ES = active_pledged[groups["ES"]]
FR = active_pledged[groups["FR"]]
GB = active_pledged[groups["GB"]]
HK = active_pledged[groups["HK"]]
IE = active_pledged[groups["IE"]]
IT = active_pledged[groups["IT"]]
LU = active_pledged[groups["LU"]]
MX = active_pledged[groups["MX"]]
NL = active_pledged[groups["NL"]]
NO = active_pledged[groups["NO"]]
NZ = active_pledged[groups["NZ"]]
SE = active_pledged[groups["SE"]]
SG = active_pledged[groups["SG"]]
US = active_pledged[groups["US"]]

#Performing ANOVA
stats.f_oneway(AT,AU,BE,CA,CH,DE,DK,ES,FR,GB,HK,IE,IT,LU,MX,NL,NO,NZ,SE,SG,US)
# Out:
# F_onewayResult(statistic=1.0567294774890663, pvalue=0.39119653280708244)

# %%
np.random.seed()
countries = ["AT","AU","BE","CA","CH","DE","DK","ES","FR","GB","HK","IE","IT","LU","MX","NL","NO","NZ","SE","SG","US"]

#Generate random data
active_country = np.random.choice(a= countries,
                                  p=[0.047, 0.047, 0.047, 0.047, 0.047, 0.047, 0.047, 0.047, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048],
                                  size=1000)

#Using a different distribution for US pledges only
USactive_pledged = stats.poisson.rvs(loc=18,
                                   mu=32,
                                   size=1000)

active_pledged = stats.poisson.rvs(loc=18,
                                   mu=30,
                                   size=1000)

active_pledged = np.where(active_country=="US", USactive_pledged, active_pledged)

#Group pledges by countries
active_frame = pd.DataFrame({"countries":active_country,"amounts":active_pledged})
groups = active_frame.groupby("countries").groups

#Extract individual countries
AT = active_pledged[groups["AT"]]
AU = active_pledged[groups["AU"]]
BE = active_pledged[groups["BE"]]
CA = active_pledged[groups["CA"]]
CH = active_pledged[groups["CH"]]
DE = active_pledged[groups["DE"]]
DK = active_pledged[groups["DK"]]
ES = active_pledged[groups["ES"]]
FR = active_pledged[groups["FR"]]
GB = active_pledged[groups["GB"]]
HK = active_pledged[groups["HK"]]
IE = active_pledged[groups["IE"]]
IT = active_pledged[groups["IT"]]
LU = active_pledged[groups["LU"]]
MX = active_pledged[groups["MX"]]
NL = active_pledged[groups["NL"]]
NO = active_pledged[groups["NO"]]
NZ = active_pledged[groups["NZ"]]
SE = active_pledged[groups["SE"]]
SG = active_pledged[groups["SG"]]
US = active_pledged[groups["US"]]

#Performing ANOVA
stats.f_oneway(AT,AU,BE,CA,CH,DE,DK,ES,FR,GB,HK,IE,IT,LU,MX,NL,NO,NZ,SE,SG,US)
# Out:
# F_onewayResult(statistic=0.98230673536901492, pvalue=0.48129108003811161)

# %%
#Get all countries' pairs
country_pairs =[]

for country1 in range(19):
    for country2 in range(country1+1,20):
        country_pairs.append((countries[country1], countries[country2]))
        
#T-test on each pair
for country1, country2 in country_pairs:
    print(country1, country2)
    print(stats.ttest_ind(active_pledged[groups[country1]],
                         active_pledged[groups[country2]]))
# Out:
# AT AU
# Ttest_indResult(statistic=-0.92523876521246984, pvalue=0.3575566865570442)
# AT BE
# Ttest_indResult(statistic=-0.63198283494476992, pvalue=0.52905535946720228)
# AT CA
# Ttest_indResult(statistic=-0.43494279429531824, pvalue=0.66470626163563218)
# AT CH
# Ttest_indResult(statistic=-0.43910982091590295, pvalue=0.6617511281243833)
# AT DE
# Ttest_indResult(statistic=-0.29077432146676013, pvalue=0.77202649115810418)
# AT DK
# Ttest_indResult(statistic=-0.62662103992206242, pvalue=0.53281040802167801)
# AT ES
# Ttest_indResult(statistic=-0.63399143902668575, pvalue=0.52774983981780621)
# AT FR
# Ttest_indResult(statistic=-0.82673972839387366, pvalue=0.41067254819065691)
# AT GB
# Ttest_indResult(statistic=-1.551138554017168, pvalue=0.12441735580470595)
# AT HK
# Ttest_indResult(statistic=-0.9708618337300684, pvalue=0.33437171232313834)
# AT IE
# Ttest_indResult(statistic=-0.073455212758622601, pvalue=0.94161446214478428)
# AT IT
# Ttest_indResult(statistic=-1.0864810569825718, pvalue=0.28033774576601039)
# AT LU
# Ttest_indResult(statistic=0.15029649916919841, pvalue=0.88091377403385795)
# AT MX
# Ttest_indResult(statistic=-0.69903176094825259, pvalue=0.48655955932106265)
# AT NL
# Ttest_indResult(statistic=-0.60842538783212052, pvalue=0.544587076671179)
# AT NO
# Ttest_indResult(statistic=-0.36703676660702106, pvalue=0.71461159943299934)
# AT NZ
# Ttest_indResult(statistic=-1.8261496304838145, pvalue=0.071861495085653829)
# AT SE
# Ttest_indResult(statistic=-0.47831159869314643, pvalue=0.63383855280083479)
# AT SG
# Ttest_indResult(statistic=-0.87906251899283883, pvalue=0.38217516434589027)
# AU BE
# Ttest_indResult(statistic=0.35416155600285415, pvalue=0.72395612724139402)
# AU CA
# Ttest_indResult(statistic=0.58973574710299526, pvalue=0.5567113840554665)
# AU CH
# Ttest_indResult(statistic=0.56755118461329757, pvalue=0.57167858583134046)
# AU DE
# Ttest_indResult(statistic=0.60894986832808429, pvalue=0.54410892083229934)
# AU DK
# Ttest_indResult(statistic=0.23282363618374807, pvalue=0.81643295788455372)
# AU ES
# Ttest_indResult(statistic=0.43779177090728433, pvalue=0.66247204759795997)
# AU FR
# Ttest_indResult(statistic=0.12776944635757015, pvalue=0.89858801952562406)
# AU GB
# Ttest_indResult(statistic=-0.8101921617914063, pvalue=0.41969767282393822)
# AU HK
# Ttest_indResult(statistic=0.057538106203931905, pvalue=0.95423252588101404)
# AU IE
# Ttest_indResult(statistic=1.035604461925751, pvalue=0.30288455324315439)
# AU IT
# Ttest_indResult(statistic=-0.22649197082079792, pvalue=0.82128579390615042)
# AU LU
# Ttest_indResult(statistic=1.2460356914109108, pvalue=0.21588106744281113)
# AU MX
# Ttest_indResult(statistic=0.14717679238216316, pvalue=0.88330768848231966)
# AU NL
# Ttest_indResult(statistic=0.32433309897698831, pvalue=0.74639148939583655)
# AU NO
# Ttest_indResult(statistic=0.58040370024992227, pvalue=0.56309282661120574)
# AU NZ
# Ttest_indResult(statistic=-1.1727763595873393, pvalue=0.24405037006294988)
# AU SE
# Ttest_indResult(statistic=0.45226190185457871, pvalue=0.65219321071969039)
# AU SG
# Ttest_indResult(statistic=-0.080414047074040165, pvalue=0.93608850431989032)
# BE CA
# Ttest_indResult(statistic=0.23657295128476682, pvalue=0.81345343386021818)
# BE CH
# Ttest_indResult(statistic=0.21921750570536394, pvalue=0.8269274425630736)
# BE DE
# Ttest_indResult(statistic=0.30609709477309782, pvalue=0.76020763415206472)
# BE DK
# Ttest_indResult(statistic=-0.081179666905291659, pvalue=0.93547166650458058)
# BE ES
# Ttest_indResult(statistic=0.055772320625673798, pvalue=0.95562817526394217)
# BE FR
# Ttest_indResult(statistic=-0.22966103130773119, pvalue=0.81880196865755017)
# BE GB
# Ttest_indResult(statistic=-1.1567764849916193, pvalue=0.24991594203769432)
# BE HK
# Ttest_indResult(statistic=-0.33071698100801722, pvalue=0.74152363333441729)
# BE IE
# Ttest_indResult(statistic=0.68000548214402889, pvalue=0.49799753195289043)
# BE IT
# Ttest_indResult(statistic=-0.57287781557258366, pvalue=0.56796395777924391)
# BE LU
# Ttest_indResult(statistic=0.90827244820197506, pvalue=0.36596247047331443)
# BE MX
# Ttest_indResult(statistic=-0.16805067194069381, pvalue=0.86688624724009478)
# BE NL
# Ttest_indResult(statistic=-0.011417155862290577, pvalue=0.99091314717380508)
# BE NO
# Ttest_indResult(statistic=0.25592418318542376, pvalue=0.79856271814217272)
# BE NZ
# Ttest_indResult(statistic=-1.4992758901583469, pvalue=0.13718912315717413)
# BE SE
# Ttest_indResult(statistic=0.12524273067355859, pvalue=0.90060172585996057)
# BE SG
# Ttest_indResult(statistic=-0.39293702753958593, pvalue=0.69525568859010789)
# CA CH
# Ttest_indResult(statistic=-0.013260575823467227, pvalue=0.98944685969580026)
# CA DE
# Ttest_indResult(statistic=0.10128087286996865, pvalue=0.91954790457333957)
# CA DK
# Ttest_indResult(statistic=-0.29047218575148803, pvalue=0.77210878445515374)
# CA ES
# Ttest_indResult(statistic=-0.19828496813693008, pvalue=0.84320919446525533)
# CA FR
# Ttest_indResult(statistic=-0.46729196076378171, pvalue=0.64127808501971351)
# CA GB
# Ttest_indResult(statistic=-1.375199374826066, pvalue=0.17196919632279106)
# CA HK
# Ttest_indResult(statistic=-0.5902970198477524, pvalue=0.55629709456468457)
# CA IE
# Ttest_indResult(statistic=0.44030370215271247, pvalue=0.66063979063712974)
# CA IT
# Ttest_indResult(statistic=-0.80054319702157661, pvalue=0.42525684123539831)
# CA LU
# Ttest_indResult(statistic=0.68141164666951215, pvalue=0.4972515791751565)
# CA MX
# Ttest_indResult(statistic=-0.37748489082632775, pvalue=0.70663796971031245)
# CA NL
# Ttest_indResult(statistic=-0.23568107610937697, pvalue=0.81416701837678185)
# CA NO
# Ttest_indResult(statistic=0.0387684194451774, pvalue=0.96915812497157217)
# CA NZ
# Ttest_indResult(statistic=-1.7152429904980926, pvalue=0.089703997362804114)
# CA SE
# Ttest_indResult(statistic=-0.09254050864662472, pvalue=0.92647203370194764)
# CA SG
# Ttest_indResult(statistic=-0.59935958879066764, pvalue=0.55040629911610328)
# CH DE
# Ttest_indResult(statistic=0.11085309622519977, pvalue=0.91198527525363859)
# CH DK
# Ttest_indResult(statistic=-0.27374106692401634, pvalue=0.78492509998002113)
# CH ES
# Ttest_indResult(statistic=-0.18126438581410828, pvalue=0.85652694840959143)
# CH FR
# Ttest_indResult(statistic=-0.44618424164039988, pvalue=0.65643853420177356)
# CH GB
# Ttest_indResult(statistic=-1.3344357475433524, pvalue=0.18503246928485129)
# CH HK
# Ttest_indResult(statistic=-0.56881572465330132, pvalue=0.57078247956290495)
# CH IE
# Ttest_indResult(statistic=0.44651923259859072, pvalue=0.65619742090420008)
# CH IT
# Ttest_indResult(statistic=-0.77333949433752724, pvalue=0.44118287987247862)
# CH LU
# Ttest_indResult(statistic=0.68355914784016525, pvalue=0.49597159758471965)
# CH MX
# Ttest_indResult(statistic=-0.35837394713657933, pvalue=0.72087569126900808)
# CH NL
# Ttest_indResult(statistic=-0.21897741738981166, pvalue=0.82713740887560516)
# CH NO
# Ttest_indResult(statistic=0.050327320550509105, pvalue=0.95997433021317957)
# CH NZ
# Ttest_indResult(statistic=-1.6771579364305162, pvalue=0.097101182501555861)
# CH SE
# Ttest_indResult(statistic=-0.078940790574361083, pvalue=0.93726100712423932)
# CH SG
# Ttest_indResult(statistic=-0.57715173243060669, pvalue=0.56531059238014114)
# DE DK
# Ttest_indResult(statistic=-0.34083046842686604, pvalue=0.73410292317739922)
# DE ES
# Ttest_indResult(statistic=-0.27896975938191321, pvalue=0.78088085902690896)
# DE FR
# Ttest_indResult(statistic=-0.50561275868965905, pvalue=0.61432481265214156)
# DE GB
# Ttest_indResult(statistic=-1.2917091411205579, pvalue=0.19955911315826824)
# DE HK
# Ttest_indResult(statistic=-0.61609943691577818, pvalue=0.53935028128865825)
# DE IE
# Ttest_indResult(statistic=0.27773480778715176, pvalue=0.78183242224230687)
# DE IT
# Ttest_indResult(statistic=-0.79125778658497681, pvalue=0.43082879658237105)
# DE LU
# Ttest_indResult(statistic=0.49050941177145768, pvalue=0.62502267259801036)
# DE MX
# Ttest_indResult(statistic=-0.41789092418935608, pvalue=0.67705648546239439)
# DE NL
# Ttest_indResult(statistic=-0.30011237976030603, pvalue=0.76479129020589709)
# DE NO
# Ttest_indResult(statistic=-0.05944977623163946, pvalue=0.95273677362725251)
# DE NZ
# Ttest_indResult(statistic=-1.5698219836229035, pvalue=0.12035495033661062)
# DE SE
# Ttest_indResult(statistic=-0.1727011197114412, pvalue=0.86331717012396192)
# DE SG
# Ttest_indResult(statistic=-0.60728082020298757, pvalue=0.54534256664539504)
# DK ES
# Ttest_indResult(statistic=0.13642841775127912, pvalue=0.89177437344289479)
# DK FR
# Ttest_indResult(statistic=-0.12169743212455036, pvalue=0.90340121967030251)
# DK GB
# Ttest_indResult(statistic=-0.9465104919811691, pvalue=0.346264652623678)
# DK HK
# Ttest_indResult(statistic=-0.20451139460208576, pvalue=0.83840564673653184)
# DK IE
# Ttest_indResult(statistic=0.6839630315393419, pvalue=0.49569925661265379)
# DK IT
# Ttest_indResult(statistic=-0.42839664040330044, pvalue=0.66936368122311074)
# DK LU
# Ttest_indResult(statistic=0.88169342698370856, pvalue=0.38040026159753126)
# DK MX
# Ttest_indResult(statistic=-0.076519716690638631, pvalue=0.93918132452084413)
# DK NL
# Ttest_indResult(statistic=0.066859220712286602, pvalue=0.94684374495677592)
# DK NO
# Ttest_indResult(statistic=0.30089275813181948, pvalue=0.76424873231127954)
# DK NZ
# Ttest_indResult(statistic=-1.2531166573701389, pvalue=0.21376859029333042)
# DK SE
# Ttest_indResult(statistic=0.18548198061881371, pvalue=0.85331469281493444)
# DK SG
# Ttest_indResult(statistic=-0.27657082710969055, pvalue=0.78280559160281526)
# ES FR
# Ttest_indResult(statistic=-0.30274350610601752, pvalue=0.76268428495147922)
# ES GB
# Ttest_indResult(statistic=-1.2789368678575899, pvalue=0.20366051811263078)
# ES HK
# Ttest_indResult(statistic=-0.42235259381521606, pvalue=0.67363956511380807)
# ES IE
# Ttest_indResult(statistic=0.67416405143346192, pvalue=0.50168854690348663)
# ES IT
# Ttest_indResult(statistic=-0.66637784233162545, pvalue=0.50664518399127023)
# ES LU
# Ttest_indResult(statistic=0.92494636747242398, pvalue=0.35726582308504773)
# ES MX
# Ttest_indResult(statistic=-0.22809460680398938, pvalue=0.82004314183322136)
# ES NL
# Ttest_indResult(statistic=-0.065075689993798216, pvalue=0.94824236743010548)
# ES NO
# Ttest_indResult(statistic=0.2240138004801128, pvalue=0.82322762412644102)
# ES NZ
# Ttest_indResult(statistic=-1.6687725691023871, pvalue=0.098525812758574458)
# ES SE
# Ttest_indResult(statistic=0.083637947465577789, pvalue=0.9335240636754647)
# ES SG
# Ttest_indResult(statistic=-0.46940535784379345, pvalue=0.63986692690910019)
# FR GB
# Ttest_indResult(statistic=-0.94352698253288148, pvalue=0.34753700205236215)
# FR HK
# Ttest_indResult(statistic=-0.082514897896089567, pvalue=0.93439741476272775)
# FR IE
# Ttest_indResult(statistic=0.91588477603356788, pvalue=0.36184616763913402)
# FR IT
# Ttest_indResult(statistic=-0.35331869614799938, pvalue=0.72457163884703846)
# FR LU
# Ttest_indResult(statistic=1.133775225460135, pvalue=0.25968318297646092)
# FR MX
# Ttest_indResult(statistic=0.035239884322882054, pvalue=0.97196013854696628)
# FR NL
# Ttest_indResult(statistic=0.20626624050822148, pvalue=0.8370023182292966)
# FR NO
# Ttest_indResult(statistic=0.46803386707129829, pvalue=0.64084375876429944)
# FR NZ
# Ttest_indResult(statistic=-1.2992956139269527, pvalue=0.1970891142669477)
# FR SE
# Ttest_indResult(statistic=0.33747313599498924, pvalue=0.73652901717958463)
# FR SG
# Ttest_indResult(statistic=-0.19371566540174859, pvalue=0.84682100336543253)
# GB HK
# Ttest_indResult(statistic=0.93231602903799893, pvalue=0.35329193763846445)
# GB IE
# Ttest_indResult(statistic=1.8062043252282705, pvalue=0.073697538981547392)
# GB IT
# Ttest_indResult(statistic=0.57909477550837563, pvalue=0.56375382256674844)
# GB LU
# Ttest_indResult(statistic=1.955040846398669, pvalue=0.053369864747531366)
# GB MX
# Ttest_indResult(statistic=0.87510266537839643, pvalue=0.38359435326084002)
# GB NL
# Ttest_indResult(statistic=1.0867158047765761, pvalue=0.27969905126728167)
# GB NO
# Ttest_indResult(statistic=1.2969087253959228, pvalue=0.19773907791444986)
# GB NZ
# Ttest_indResult(statistic=-0.36117604791934876, pvalue=0.71876981615873503)
# GB SE
# Ttest_indResult(statistic=1.1721367937591431, pvalue=0.24407321933105328)
# GB SG
# Ttest_indResult(statistic=0.64221740005334671, pvalue=0.52226273232096476)
# HK IE
# Ttest_indResult(statistic=1.0796412664814159, pvalue=0.28282362836121694)
# HK IT
# Ttest_indResult(statistic=-0.30290020601884121, pvalue=0.76258279546227981)
# HK LU
# Ttest_indResult(statistic=1.3173634220133099, pvalue=0.19085239063495454)
# HK MX
# Ttest_indResult(statistic=0.10983447988372735, pvalue=0.91276756060829123)
# HK NL
# Ttest_indResult(statistic=0.3008611698279991, pvalue=0.76415130873724935)
# HK NO
# Ttest_indResult(statistic=0.58565292350918485, pvalue=0.55952730865972711)
# HK NZ
# Ttest_indResult(statistic=-1.3464776794626083, pvalue=0.18149276613137305)
# HK SE
# Ttest_indResult(statistic=0.44630212119769741, pvalue=0.65643922758270024)
# HK SG
# Ttest_indResult(statistic=-0.13811463793399567, pvalue=0.8904516663827089)
# IE IT
# Ttest_indResult(statistic=-1.2360685239368694, pvalue=0.21924456347071394)
# IE LU
# Ttest_indResult(statistic=0.26717728877757208, pvalue=0.78989988540299538)
# IE MX
# Ttest_indResult(statistic=-0.77286886430461099, pvalue=0.4414600835039536)
# IE NL
# Ttest_indResult(statistic=-0.65620573742255339, pvalue=0.5131988654939651)
# IE NO
# Ttest_indResult(statistic=-0.36506191786321679, pvalue=0.71588527972444405)
# IE NZ
# Ttest_indResult(statistic=-2.1377540773677395, pvalue=0.035187847865491492)
# IE SE
# Ttest_indResult(statistic=-0.49953473557449046, pvalue=0.61859529146845738)
# IE SG
# Ttest_indResult(statistic=-0.99218005099753426, pvalue=0.32368419738875909)
# IT LU
# Ttest_indResult(statistic=1.4256237700235028, pvalue=0.15722046928395553)
# IT MX
# Ttest_indResult(statistic=0.34707955536175672, pvalue=0.7292834420272738)
# IT NL
# Ttest_indResult(statistic=0.53220874133925289, pvalue=0.59577383883740853)
# IT NO
# Ttest_indResult(statistic=0.7720315574810509, pvalue=0.4420531704931645)
# IT NZ
# Ttest_indResult(statistic=-0.92791687872835515, pvalue=0.35590537481696949)
# IT SE
# Ttest_indResult(statistic=0.64661714946685922, pvalue=0.51950734085834616)
# IT SG
# Ttest_indResult(statistic=0.1214556756129378, pvalue=0.9035950083535238)
# LU MX
# Ttest_indResult(statistic=-0.96479865886258953, pvalue=0.33720263102585124)
# LU NL
# Ttest_indResult(statistic=-0.87181175428175195, pvalue=0.38555622657029887)
# LU NO
# Ttest_indResult(statistic=-0.58863905204974143, pvalue=0.55762862585195838)
# LU NZ
# Ttest_indResult(statistic=-2.2695938806060343, pvalue=0.025763472170438378)
# LU SE
# Ttest_indResult(statistic=-0.71784642797768239, pvalue=0.47482033060796958)
# LU SG
# Ttest_indResult(statistic=-1.1706536765298128, pvalue=0.24497165748398744)
# MX NL
# Ttest_indResult(statistic=0.14924290685402644, pvalue=0.88168169321622802)
# MX NO
# Ttest_indResult(statistic=0.38047570260445251, pvalue=0.70450918902056459)
# MX NZ
# Ttest_indResult(statistic=-1.1745131118150647, pvalue=0.24343154722804558)
# MX SE
# Ttest_indResult(statistic=0.26434302936144444, pvalue=0.79214806978750296)
# MX SG
# Ttest_indResult(statistic=-0.20221950661505014, pvalue=0.84021725051814955)
# NL NO
# Ttest_indResult(statistic=0.25304394038230477, pvalue=0.80081134707290724)
# NL NZ
# Ttest_indResult(statistic=-1.4104780754017552, pvalue=0.16192367928074092)
# NL SE
# Ttest_indResult(statistic=0.12916889668671652, pvalue=0.89751877832656002)
# NL SG
# Ttest_indResult(statistic=-0.36255894537215283, pvalue=0.71779393873590169)
# NO NZ
# Ttest_indResult(statistic=-1.6108635521604038, pvalue=0.11105237008989394)
# NO SE
# Ttest_indResult(statistic=-0.12076983491950127, pvalue=0.90416878182666705)
# NO SG
# Ttest_indResult(statistic=-0.58384883373686924, pvalue=0.56090539968333952)
# NZ SE
# Ttest_indResult(statistic=1.4994732805219357, pvalue=0.1376870129852617)
# NZ SG
# Ttest_indResult(statistic=0.95425288830222976, pvalue=0.34279482173528308)
# SE SG
# Ttest_indResult(statistic=-0.47028987778885079, pvalue=0.63941177248025838)

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

tukey = pairwise_tukeyhsd(endog=active_pledged,
                         groups=active_country,
                         alpha=0.05)

tukey.plot_simultaneous()
plt.vlines(x=49.57,ymin=-0.5,ymax=4.5,color="red")

tukey.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
