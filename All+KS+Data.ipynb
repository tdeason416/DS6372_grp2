# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style('darkgrid')

import scipy
import statsmodels
import statsmodels.api as sm
from statsmodels.formula.api import ols

import scipy.stats as stats
import matplotlib.pyplot as plt
import math

import os
# Out:
# /Users/vanessatorres/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
print(os.listdir("../vanessatorres/desktop/kickstarter-projects"))
# Out:
# ['.DS_Store', '.ipynb_checkpoints', '.Rapp.history', 'KS', 'ks-projects-201612.csv', 'ks-projects-201801.csv']

# %%
df_ks16 = pd.read_csv("../vanessatorres/desktop/kickstarter-projects/ks-projects-201612.csv", encoding='ISO-8859-14')
# Out:
# /Users/vanessatorres/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_ks16.drop(['Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16'], axis=1, inplace=True)

# %%
cols = df_ks16.columns.tolist()
for entry in np.arange(0,len(cols),1):
    cols[entry] = cols[entry].rstrip()
df_ks16.columns = cols
df_ks16.columns

df_ks16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 323750 entries, 0 to 323749
# Data columns (total 13 columns):
# ID               323750 non-null int64
# name             323748 non-null object
# category         323745 non-null object
# main_category    323750 non-null object
# currency         323750 non-null object
# deadline         323750 non-null object
# goal             323750 non-null object
# launched         323750 non-null object
# pledged          323750 non-null object
# state            323750 non-null object
# backers          323750 non-null object
# country          323750 non-null object
# usd pledged      319960 non-null object
# dtypes: int64(1), object(12)
# memory usage: 32.1+ MB

# %%
df_ks18 = pd.read_csv("../vanessatorres/desktop/kickstarter-projects/ks-projects-201801.csv", encoding='ISO-8859-14')

# %%
df_ks18.drop(['usd_pledged_real', 'usd_goal_real'], axis=1, inplace=True)

# %%
df_ks18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378661 entries, 0 to 378660
# Data columns (total 13 columns):
# ID               378661 non-null int64
# name             378657 non-null object
# category         378661 non-null object
# main_category    378661 non-null object
# currency         378661 non-null object
# deadline         378661 non-null object
# goal             378661 non-null float64
# launched         378661 non-null object
# pledged          378661 non-null float64
# state            378661 non-null object
# backers          378661 non-null int64
# country          378661 non-null object
# usd pledged      374864 non-null float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 37.6+ MB

# %%
df_ks = pd.concat([df_ks16, df_ks18])

# %%
df_ks[['goal', 'pledged', 'usd pledged', 'backers']] = df_ks[['goal', 'pledged', 'usd pledged', 'backers']].apply(pd.to_numeric, errors='coerce')
df_ks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 702411 entries, 0 to 378660
# Data columns (total 13 columns):
# ID               702411 non-null int64
# name             702405 non-null object
# category         702406 non-null object
# main_category    702411 non-null object
# currency         702411 non-null object
# deadline         702411 non-null object
# goal             701779 non-null float64
# launched         702411 non-null object
# pledged          701787 non-null float64
# state            702411 non-null object
# backers          701788 non-null float64
# country          702411 non-null object
# usd pledged      694201 non-null float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 75.0+ MB

# %%
df_ks['usd pledged'] = df_ks['usd pledged'].fillna(0)

# %%
df_ks['state'].value_counts() < 100
states = ['failed', 'successful', 'live', 'undefined', 'suspended']

# %%
df_ks = df_ks[df_ks['state'].isin(states)]

# %%
percentual_success = round(df_ks["state"].value_counts() / len(df_ks["state"]) * 100,2)

print("State Percentual in %:")
print(percentual_success)

plt.figure(figsize=(12,6))
sns.countplot(x='state', data=df_ks)

axl = sns.countplot(x="state", data=df_ks)
axl.set_xticklabels(axl.get_xticklabels(),rotation=45)
axl.set_title("Status Project Distribution", fontsize=15)
axl.set_xlabel("State Description", fontsize=12)
axl.set_ylabel("Count", fontsize=12)

plt.show()
# Out:
# State Percentual in %:
# failed        58.69
# successful    39.62
# live           1.16
# suspended      0.53
# Name: state, dtype: float64

# %%
df_ks.isnull().sum()
# Out:
# ID               0
# name             0
# category         0
# main_category    0
# currency         0
# deadline         0
# goal             0
# launched         0
# pledged          0
# state            0
# backers          0
# country          0
# usd pledged      0
# dtype: int64

# %%
df_ks = df_ks.drop(df_ks[df_ks['name'].isnull() == True].index)

# %%
df_ks = df_ks.drop(df_ks[df_ks['goal'].isnull() == True].index)

# %%
df_ks = df_ks.drop(df_ks[df_ks['pledged'].isnull() == True].index)

# %%
df_ks = df_ks.drop(df_ks[df_ks['backers'].isnull() == True].index)

# %%
df_ks.isnull().sum()
# Out:
# ID               0
# name             0
# category         0
# main_category    0
# currency         0
# deadline         0
# goal             0
# launched         0
# pledged          0
# state            0
# backers          0
# country          0
# usd pledged      0
# dtype: int64

# %%
df_ks.describe()
# Out:
#                  ID          goal       pledged        backers   usd pledged
# count  6.169360e+05  6.169360e+05  6.169360e+05  616936.000000  6.169360e+05
# mean   1.074400e+09  4.422993e+04  1.007747e+04     114.096157  8.034540e+03
# std    6.190220e+08  1.123862e+06  9.779999e+04     975.215361  8.526672e+04
# min    5.971000e+03  1.000000e-02  0.000000e+00       0.000000  0.000000e+00
# 25%    5.378556e+08  2.000000e+03  4.700000e+01       2.000000  2.700000e+01
# 50%    1.074278e+09  5.000000e+03  7.630000e+02      15.000000  5.595496e+02
# 75%    1.609944e+09  1.500000e+04  4.525000e+03      62.000000  3.646230e+03
# max    2.147476e+09  1.000000e+08  2.033899e+07  219382.000000  2.033899e+07

# %%
#Nulls removed
percentual_success = round(df_ks["state"].value_counts() / len(df_ks["state"]) * 100,2)

print("State Percentual in %:")
print(percentual_success)

plt.figure(figsize=(12,6))
sns.countplot(x='state', data=df_ks)

axl = sns.countplot(x="state", data=df_ks)
axl.set_xticklabels(axl.get_xticklabels(),rotation=45)
axl.set_title("Status Project Distribution", fontsize=15)
axl.set_xlabel("State Description", fontsize=12)
axl.set_ylabel("Count", fontsize=12)

plt.show()
# Out:
# State Percentual in %:
# failed        58.69
# successful    39.62
# live           1.16
# suspended      0.53
# Name: state, dtype: float64

# %%
plt.figure(figsize=(16,6))
sns.countplot(x='main_category', data=df_ks, hue='state')
plt.legend(loc='upper center')
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>

# %%
plt.figure(figsize=(16,6))
sns.countplot(x='country', data=df_ks, hue='state')
plt.legend(loc='upper center')
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>

# %%
df_ks_lm = ols('goal ~ main_category', data=df_ks).fit()
print(sm.stats.anova_lm(df_ks_lm, type=2))
# Out:
#                      df        sum_sq       mean_sq          F        PR(>F)
# main_category      14.0  5.465488e+14  3.903920e+13  30.929282  1.485560e-83
# Residual       616921.0  7.786829e+17  1.262208e+12        NaN           NaN
# /Users/vanessatorres/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/vanessatorres/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Users/vanessatorres/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
df_ks_lm = ols('goal ~ country', data=df_ks).fit()
print(sm.stats.anova_lm(df_ks_lm, type=2))
# Out:
#                 df        sum_sq       mean_sq          F        PR(>F)
# country       21.0  5.264423e+14  2.506868e+13  19.860229  2.893119e-75
# Residual  616914.0  7.787030e+17  1.262255e+12        NaN           NaN
# /Users/vanessatorres/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/vanessatorres/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Users/vanessatorres/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
groupby_country = df_ks.groupby('country')
for country, value in groupby_country['goal']:
    print((country, value.mean()))
# Out:
# ('AT', 38380.289570552144)
# ('AU', 73042.00224364302)
# ('BE', 33015.90202702703)
# ('CA', 57894.41988681581)
# ('CH', 301247.82844036695)
# ('DE', 60644.21552321552)
# ('DK', 141628.78255602665)
# ('ES', 47307.51240734773)
# ('FR', 86152.97439544808)
# ('GB', 26905.18102005134)
# ('HK', 187972.08910891088)
# ('IE', 43790.364478114476)
# ('IT', 71396.36575481256)
# ('JP', 1298777.1875)
# ('LU', 26508.252631578947)
# ('MX', 257329.2781341108)
# ('NL', 64567.174370709385)
# ('NO', 291690.3056894889)
# ('NZ', 34241.417539267015)
# ('SE', 306986.33917015605)
# ('SG', 21172.415254237287)
# ('US', 40110.518132227386)

# %%
groupby_country = df_ks.groupby('main_category')
for country, value in groupby_country['goal']:
    print((country, value.mean()))
# Out:
# ('Art', 37447.22000063073)
# ('Comics', 22241.9599024773)
# ('Crafts', 11077.036253143337)
# ('Dance', 8803.813234859674)
# ('Design', 43189.23427741908)
# ('Fashion', 24354.45921414102)
# ('Film & Video', 74558.0921960361)
# ('Food', 48898.48107700514)
# ('Games', 42918.250236594584)
# ('Journalism', 99855.26700488054)
# ('Music', 14953.97644944571)
# ('Photography', 11581.00266304348)
# ('Publishing', 21657.645604587837)
# ('Technology', 113185.31963549313)
# ('Theater', 22292.310445948027)

# %%
np.random.seed()
countries = ["AT","AU","BE","CA","CH","DE","DK","ES","FR","GB","HK","IE","IT","LU","MX","NL","NO","NZ","SE","SG","US"]

#Generate random data
active_country = np.random.choice(a= countries,
                                  p=[0.047, 0.047, 0.047, 0.047, 0.047, 0.047, 0.047, 0.047, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048],
                                  size=1000)

active_pledged = stats.poisson.rvs(loc=18,
                                   mu=30,
                                   size=1000)

active_frame = pd.DataFrame({"countries":active_country,"amounts":active_pledged})
groups = active_frame.groupby("countries").groups

#Extract individual countries
AT = active_pledged[groups["AT"]]
AU = active_pledged[groups["AU"]]
BE = active_pledged[groups["BE"]]
CA = active_pledged[groups["CA"]]
CH = active_pledged[groups["CH"]]
DE = active_pledged[groups["DE"]]
DK = active_pledged[groups["DK"]]
ES = active_pledged[groups["ES"]]
FR = active_pledged[groups["FR"]]
GB = active_pledged[groups["GB"]]
HK = active_pledged[groups["HK"]]
IE = active_pledged[groups["IE"]]
IT = active_pledged[groups["IT"]]
LU = active_pledged[groups["LU"]]
MX = active_pledged[groups["MX"]]
NL = active_pledged[groups["NL"]]
NO = active_pledged[groups["NO"]]
NZ = active_pledged[groups["NZ"]]
SE = active_pledged[groups["SE"]]
SG = active_pledged[groups["SG"]]
US = active_pledged[groups["US"]]

#Performing ANOVA
stats.f_oneway(AT,AU,BE,CA,CH,DE,DK,ES,FR,GB,HK,IE,IT,LU,MX,NL,NO,NZ,SE,SG,US)
# Out:
# F_onewayResult(statistic=0.6316386940387213, pvalue=0.89120948386961063)

# %%
np.random.seed()
countries = ["AT","AU","BE","CA","CH","DE","DK","ES","FR","GB","HK","IE","IT","LU","MX","NL","NO","NZ","SE","SG","US"]

#Generate random data
active_country = np.random.choice(a= countries,
                                  p=[0.047, 0.047, 0.047, 0.047, 0.047, 0.047, 0.047, 0.047, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048, 0.048],
                                  size=1000)

#Using a different distribution for US pledges only
USactive_pledged = stats.poisson.rvs(loc=18,
                                   mu=32,
                                   size=1000)

active_pledged = stats.poisson.rvs(loc=18,
                                   mu=30,
                                   size=1000)

active_pledged = np.where(active_country=="US", USactive_pledged, active_pledged)

#Group pledges by countries
active_frame = pd.DataFrame({"countries":active_country,"amounts":active_pledged})
groups = active_frame.groupby("countries").groups

#Extract individual countries
AT = active_pledged[groups["AT"]]
AU = active_pledged[groups["AU"]]
BE = active_pledged[groups["BE"]]
CA = active_pledged[groups["CA"]]
CH = active_pledged[groups["CH"]]
DE = active_pledged[groups["DE"]]
DK = active_pledged[groups["DK"]]
ES = active_pledged[groups["ES"]]
FR = active_pledged[groups["FR"]]
GB = active_pledged[groups["GB"]]
HK = active_pledged[groups["HK"]]
IE = active_pledged[groups["IE"]]
IT = active_pledged[groups["IT"]]
LU = active_pledged[groups["LU"]]
MX = active_pledged[groups["MX"]]
NL = active_pledged[groups["NL"]]
NO = active_pledged[groups["NO"]]
NZ = active_pledged[groups["NZ"]]
SE = active_pledged[groups["SE"]]
SG = active_pledged[groups["SG"]]
US = active_pledged[groups["US"]]

#Performing ANOVA
stats.f_oneway(AT,AU,BE,CA,CH,DE,DK,ES,FR,GB,HK,IE,IT,LU,MX,NL,NO,NZ,SE,SG,US)
# Out:
# F_onewayResult(statistic=1.6463243852338589, pvalue=0.036558718598046762)

# %%
#Get all countries' pairs
country_pairs =[]

for country1 in range(19):
    for country2 in range(country1+1,20):
        country_pairs.append((countries[country1], countries[country2]))
        
#T-test on each pair
for country1, country2 in country_pairs:
    print(country1, country2)
    print(stats.ttest_ind(active_pledged[groups[country1]],
                         active_pledged[groups[country2]]))
# Out:
# AT AU
# Ttest_indResult(statistic=0.44561760665174949, pvalue=0.65677381539323898)
# AT BE
# Ttest_indResult(statistic=0.23757774948185248, pvalue=0.81274268686656126)
# AT CA
# Ttest_indResult(statistic=1.6854095061962828, pvalue=0.095226675822535328)
# AT CH
# Ttest_indResult(statistic=0.70195358734377422, pvalue=0.48456056886046672)
# AT DE
# Ttest_indResult(statistic=0.47509870328378417, pvalue=0.6357737751627599)
# AT DK
# Ttest_indResult(statistic=0.20827393534002664, pvalue=0.83548053084270446)
# AT ES
# Ttest_indResult(statistic=0.83058077343670322, pvalue=0.40848404832776453)
# AT FR
# Ttest_indResult(statistic=-0.6504846645290554, pvalue=0.51703636073244996)
# AT GB
# Ttest_indResult(statistic=-0.49094284151454615, pvalue=0.62461109639019052)
# AT HK
# Ttest_indResult(statistic=-0.17931800980467688, pvalue=0.85802091457100083)
# AT IE
# Ttest_indResult(statistic=-1.8924611795865567, pvalue=0.061210307032090377)
# AT IT
# Ttest_indResult(statistic=0.34369240912271132, pvalue=0.73179207028587323)
# AT LU
# Ttest_indResult(statistic=-0.32475823324476338, pvalue=0.74598086581518674)
# AT MX
# Ttest_indResult(statistic=-1.0600812810133557, pvalue=0.29163613631638446)
# AT NL
# Ttest_indResult(statistic=1.1245240748697394, pvalue=0.2635099108626961)
# AT NO
# Ttest_indResult(statistic=-1.300856316581352, pvalue=0.19642147637570054)
# AT NZ
# Ttest_indResult(statistic=-0.4932644258751297, pvalue=0.6229072731051144)
# AT SE
# Ttest_indResult(statistic=0.45081197253121702, pvalue=0.65313119583604706)
# AT SG
# Ttest_indResult(statistic=1.285960257821017, pvalue=0.201518219080318)
# AU BE
# Ttest_indResult(statistic=-0.15087383510230012, pvalue=0.88039181289787694)
# AU CA
# Ttest_indResult(statistic=1.3908740821169687, pvalue=0.16738192896751555)
# AU CH
# Ttest_indResult(statistic=0.32817537231546984, pvalue=0.74351679440050578)
# AU DE
# Ttest_indResult(statistic=0.0617096983122222, pvalue=0.95091360382354173)
# AU DK
# Ttest_indResult(statistic=-0.21029260863669338, pvalue=0.83388499267702809)
# AU ES
# Ttest_indResult(statistic=0.49030218316703761, pvalue=0.62508738680010301)
# AU FR
# Ttest_indResult(statistic=-1.1496396287557489, pvalue=0.25317832300302839)
# AU GB
# Ttest_indResult(statistic=-0.97806795385193612, pvalue=0.33042473378363169)
# AU HK
# Ttest_indResult(statistic=-0.67409966891695539, pvalue=0.50161255179926623)
# AU IE
# Ttest_indResult(statistic=-2.5623461832343288, pvalue=0.011761703982821375)
# AU IT
# Ttest_indResult(statistic=-0.084266751278789256, pvalue=0.93300328968693202)
# AU LU
# Ttest_indResult(statistic=-0.79553519890010005, pvalue=0.42794122283187974)
# AU MX
# Ttest_indResult(statistic=-1.5589001633105664, pvalue=0.1220007543541473)
# AU NL
# Ttest_indResult(statistic=0.79446306801915723, pvalue=0.42873509519428987)
# AU NO
# Ttest_indResult(statistic=-1.8566799672925349, pvalue=0.066271208448261856)
# AU NZ
# Ttest_indResult(statistic=-0.94068082190888802, pvalue=0.34902755807955133)
# AU SE
# Ttest_indResult(statistic=0.011523220960242301, pvalue=0.99082851171795339)
# AU SG
# Ttest_indResult(statistic=0.92655795966919041, pvalue=0.35634326550528683)
# BE CA
# Ttest_indResult(statistic=1.3136587599767628, pvalue=0.19258067802441067)
# BE CH
# Ttest_indResult(statistic=0.41424009555999425, pvalue=0.67984996799726916)
# BE DE
# Ttest_indResult(statistic=0.19398905095104846, pvalue=0.84663668523773472)
# BE DK
# Ttest_indResult(statistic=-0.041188114289706854, pvalue=0.96724855077691219)
# BE ES
# Ttest_indResult(statistic=0.54353282752817156, pvalue=0.58835382247167778)
# BE FR
# Ttest_indResult(statistic=-0.83355770664826367, pvalue=0.40704349239405524)
# BE GB
# Ttest_indResult(statistic=-0.68768086824217933, pvalue=0.49357105878922924)
# BE HK
# Ttest_indResult(statistic=-0.42004961015013464, pvalue=0.67536873778379602)
# BE IE
# Ttest_indResult(statistic=-2.0084328746419917, pvalue=0.047497604928379913)
# BE IT
# Ttest_indResult(statistic=0.071431488771832835, pvalue=0.94321284420568297)
# BE LU
# Ttest_indResult(statistic=-0.5336129538678599, pvalue=0.59480539609619987)
# BE MX
# Ttest_indResult(statistic=-1.1880005644379672, pvalue=0.23795885359732363)
# BE NL
# Ttest_indResult(statistic=0.80283420504729053, pvalue=0.42423359046725184)
# BE NO
# Ttest_indResult(statistic=-1.4300665017954652, pvalue=0.15636354198607427)
# BE NZ
# Ttest_indResult(statistic=-0.66756413230497835, pvalue=0.50613918346121733)
# BE SE
# Ttest_indResult(statistic=0.15976662150353482, pvalue=0.87343956284189028)
# BE SG
# Ttest_indResult(statistic=0.93174277761075042, pvalue=0.35407783722578501)
# CA CH
# Ttest_indResult(statistic=-0.97947332292309863, pvalue=0.33029894573622653)
# CA DE
# Ttest_indResult(statistic=-1.2551896855772395, pvalue=0.21265928168671808)
# CA DK
# Ttest_indResult(statistic=-1.4642031907404631, pvalue=0.14691579467554244)
# CA ES
# Ttest_indResult(statistic=-0.75084778347400993, pvalue=0.45497501254621242)
# CA FR
# Ttest_indResult(statistic=-2.3478435251810796, pvalue=0.021291913351076098)
# CA GB
# Ttest_indResult(statistic=-2.1891821117828338, pvalue=0.03129272471255979)
# CA HK
# Ttest_indResult(statistic=-1.9959877883430301, pvalue=0.048627471028958799)
# CA IE
# Ttest_indResult(statistic=-3.8302215539178661, pvalue=0.00022835457833668367)
# CA IT
# Ttest_indResult(statistic=-1.3926823708272453, pvalue=0.16703649367655601)
# CA LU
# Ttest_indResult(statistic=-1.9922501861007222, pvalue=0.049015998640589524)
# CA MX
# Ttest_indResult(statistic=-2.6065487875081748, pvalue=0.010652209275490473)
# CA NL
# Ttest_indResult(statistic=-0.47448957405345765, pvalue=0.63628749872777801)
# CA NO
# Ttest_indResult(statistic=-2.9935639441103445, pvalue=0.0035789653801892181)
# CA NZ
# Ttest_indResult(statistic=-2.0212070688550066, pvalue=0.046164353540197052)
# CA SE
# Ttest_indResult(statistic=-1.3908507132146084, pvalue=0.16773839857423589)
# CA SG
# Ttest_indResult(statistic=-0.52996194820185138, pvalue=0.59745798188916988)
# CH DE
# Ttest_indResult(statistic=-0.25409681205786694, pvalue=0.8000417271677922)
# CH DK
# Ttest_indResult(statistic=-0.49704808617107354, pvalue=0.62057141192235821)
# CH ES
# Ttest_indResult(statistic=0.167536708538085, pvalue=0.86741102416199323)
# CH FR
# Ttest_indResult(statistic=-1.3743006461690814, pvalue=0.17338759752266431)
# CH GB
# Ttest_indResult(statistic=-1.2044733153663103, pvalue=0.23195804981738391)
# CH HK
# Ttest_indResult(statistic=-0.93361290108505723, pvalue=0.35287050552548649)
# CH IE
# Ttest_indResult(statistic=-2.7117692827721536, pvalue=0.0080164954823320374)
# CH IT
# Ttest_indResult(statistic=-0.38698822610842099, pvalue=0.69970992596418313)
# CH LU
# Ttest_indResult(statistic=-1.002416868936824, pvalue=0.31866230943454865)
# CH MX
# Ttest_indResult(statistic=-1.6640743011195303, pvalue=0.0996955915178694)
# CH NL
# Ttest_indResult(statistic=0.43218950801976541, pvalue=0.66669812770271264)
# CH NO
# Ttest_indResult(statistic=-1.9986828183863408, pvalue=0.048955987975896842)
# CH NZ
# Ttest_indResult(statistic=-1.107953952613614, pvalue=0.27097080610223445)
# CH SE
# Ttest_indResult(statistic=-0.32455520260797727, pvalue=0.74633430291307712)
# CH SG
# Ttest_indResult(statistic=0.53295783035311495, pvalue=0.59548690989366881)
# DE DK
# Ttest_indResult(statistic=-0.2545093030958363, pvalue=0.7997027281013378)
# DE ES
# Ttest_indResult(statistic=0.40960104571822598, pvalue=0.68315381797484387)
# DE FR
# Ttest_indResult(statistic=-1.1422054546990494, pvalue=0.2565387622867395)
# DE GB
# Ttest_indResult(statistic=-0.97857879480153653, pvalue=0.33041129948360859)
# DE HK
# Ttest_indResult(statistic=-0.69436156975866692, pvalue=0.48898899688592246)
# DE IE
# Ttest_indResult(statistic=-2.4811416094833962, pvalue=0.014764400054781388)
# DE IT
# Ttest_indResult(statistic=-0.13760270673320485, pvalue=0.89083964641073266)
# DE LU
# Ttest_indResult(statistic=-0.80101560862502241, pvalue=0.42491443360752545)
# DE MX
# Ttest_indResult(statistic=-1.5119934444958691, pvalue=0.13378674546209038)
# DE NL
# Ttest_indResult(statistic=0.6915105470678905, pvalue=0.49093124338048733)
# DE NO
# Ttest_indResult(statistic=-1.8040188029497661, pvalue=0.074500991325979607)
# DE NZ
# Ttest_indResult(statistic=-0.93225763724862487, pvalue=0.35354210009645826)
# DE SE
# Ttest_indResult(statistic=-0.050851589876074708, pvalue=0.95955284206936931)
# DE SG
# Ttest_indResult(statistic=0.81471223322857478, pvalue=0.41731845222466113)
# DK ES
# Ttest_indResult(statistic=0.6307002575271522, pvalue=0.53012859573757454)
# DK FR
# Ttest_indResult(statistic=-0.85839622309662367, pvalue=0.39327068289036726)
# DK GB
# Ttest_indResult(statistic=-0.6955588770450889, pvalue=0.48864807519050657)
# DK HK
# Ttest_indResult(statistic=-0.39965006153130334, pvalue=0.69028397233914718)
# DK IE
# Ttest_indResult(statistic=-2.1158077981406174, pvalue=0.037033178685884779)
# DK IT
# Ttest_indResult(statistic=0.12258118532148181, pvalue=0.9027120652994064)
# DK LU
# Ttest_indResult(statistic=-0.51878292462901143, pvalue=0.60506983727783958)
# DK MX
# Ttest_indResult(statistic=-1.2135864127861005, pvalue=0.22808097577597325)
# DK NL
# Ttest_indResult(statistic=0.89485942375717464, pvalue=0.37330333199428056)
# DK NO
# Ttest_indResult(statistic=-1.4888307223049884, pvalue=0.14023292745833246)
# DK NZ
# Ttest_indResult(statistic=-0.66418825036200968, pvalue=0.50828694497665527)
# DK SE
# Ttest_indResult(statistic=0.22284294310848307, pvalue=0.82418616732396266)
# DK SG
# Ttest_indResult(statistic=1.0614893964913079, pvalue=0.2914394218103345)
# ES FR
# Ttest_indResult(statistic=-1.4520127594976879, pvalue=0.15066868657521093)
# ES GB
# Ttest_indResult(statistic=-1.2988418360195491, pvalue=0.19777654003149667)
# ES HK
# Ttest_indResult(statistic=-1.062358069385767, pvalue=0.29079488201346892)
# ES IE
# Ttest_indResult(statistic=-2.7345242113016086, pvalue=0.0075379039804636316)
# ES IT
# Ttest_indResult(statistic=-0.53596709756499528, pvalue=0.59336483281788588)
# ES LU
# Ttest_indResult(statistic=-1.1198111654940792, pvalue=0.26561740623682006)
# ES MX
# Ttest_indResult(statistic=-1.7389273389246898, pvalue=0.085625938308170155)
# ES NL
# Ttest_indResult(statistic=0.25456669334548188, pvalue=0.79967996107575856)
# ES NO
# Ttest_indResult(statistic=-2.0504555561620212, pvalue=0.043553948073804645)
# ES NZ
# Ttest_indResult(statistic=-1.2065932282198926, pvalue=0.23093626074365195)
# ES SE
# Ttest_indResult(statistic=-0.48544867652172352, pvalue=0.62865265828215344)
# ES SG
# Ttest_indResult(statistic=0.31611176789324524, pvalue=0.75272091683241948)
# FR GB
# Ttest_indResult(statistic=0.16712213893946565, pvalue=0.86768539298792879)
# FR HK
# Ttest_indResult(statistic=0.52603920825771566, pvalue=0.60006161678930547)
# FR IE
# Ttest_indResult(statistic=-1.1478638669885926, pvalue=0.25400083103511012)
# FR IT
# Ttest_indResult(statistic=1.0102271351670353, pvalue=0.31512513458094277)
# FR LU
# Ttest_indResult(statistic=0.3313015630671679, pvalue=0.74112410556815667)
# FR MX
# Ttest_indResult(statistic=-0.42041760177648363, pvalue=0.67519376438813605)
# FR NL
# Ttest_indResult(statistic=1.7070114087966433, pvalue=0.091386772594167109)
# FR NO
# Ttest_indResult(statistic=-0.63348751317033625, pvalue=0.52813644238555413)
# FR NZ
# Ttest_indResult(statistic=0.11601916174873196, pvalue=0.90790170546589577)
# FR SE
# Ttest_indResult(statistic=1.1744479982431331, pvalue=0.24349549144705729)
# FR SG
# Ttest_indResult(statistic=2.0153337315484987, pvalue=0.047029336935659471)
# GB HK
# Ttest_indResult(statistic=0.35139848278479896, pvalue=0.72602142087783406)
# GB IE
# Ttest_indResult(statistic=-1.3438770572776313, pvalue=0.18215573411999539)
# GB IT
# Ttest_indResult(statistic=0.84736110045004265, pvalue=0.39896930279904197)
# GB LU
# Ttest_indResult(statistic=0.17018948263527306, pvalue=0.865198234166066)
# GB MX
# Ttest_indResult(statistic=-0.58387747222464392, pvalue=0.56071626797207808)
# GB NL
# Ttest_indResult(statistic=1.5731964918949191, pvalue=0.11914385858316839)
# GB NO
# Ttest_indResult(statistic=-0.80682075994457014, pvalue=0.42194498968087268)
# GB NZ
# Ttest_indResult(statistic=-0.035304202573030477, pvalue=0.97191365967023202)
# GB SE
# Ttest_indResult(statistic=0.9921984473172597, pvalue=0.32379065752921321)
# GB SG
# Ttest_indResult(statistic=1.8346198780357594, pvalue=0.069903065143991888)
# HK IE
# Ttest_indResult(statistic=-1.839515529555005, pvalue=0.068511745092026968)
# HK IT
# Ttest_indResult(statistic=0.55378816328412317, pvalue=0.58086859165479865)
# HK LU
# Ttest_indResult(statistic=-0.16912863028565933, pvalue=0.86598752408952784)
# HK MX
# Ttest_indResult(statistic=-0.97179737255981924, pvalue=0.33332284020959135)
# HK NL
# Ttest_indResult(statistic=1.3795735742649868, pvalue=0.17062136500923486)
# HK NO
# Ttest_indResult(statistic=-1.2233930564480242, pvalue=0.22397276019977555)
# HK NZ
# Ttest_indResult(statistic=-0.36516917459272774, pvalue=0.71570594764091999)
# HK SE
# Ttest_indResult(statistic=0.67865457649613092, pvalue=0.49886415209723367)
# HK SG
# Ttest_indResult(statistic=1.5789791476577799, pvalue=0.11737769191387414)
# IE IT
# Ttest_indResult(statistic=2.3354346017592333, pvalue=0.021459053123660053)
# IE LU
# Ttest_indResult(statistic=1.521772588624464, pvalue=0.1308844515077614)
# IE MX
# Ttest_indResult(statistic=0.58552208078624046, pvalue=0.55947742959945046)
# IE NL
# Ttest_indResult(statistic=3.0361139131568553, pvalue=0.003048760036136469)
# IE NO
# Ttest_indResult(statistic=0.42853081033801721, pvalue=0.66920513777869983)
# IE NZ
# Ttest_indResult(statistic=1.1816895140777142, pvalue=0.24007663264353046)
# IE SE
# Ttest_indResult(statistic=2.5905111216088295, pvalue=0.011029522776708257)
# IE SG
# Ttest_indResult(statistic=3.5379220412543679, pvalue=0.00061573992099702736)
# IT LU
# Ttest_indResult(statistic=-0.67461145769333064, pvalue=0.5013510096203363)
# IT MX
# Ttest_indResult(statistic=-1.4014828525899319, pvalue=0.16416579089887334)
# IT NL
# Ttest_indResult(statistic=0.82454099562883165, pvalue=0.41163462850968824)
# IT NO
# Ttest_indResult(statistic=-1.678077308000637, pvalue=0.096618960832444561)
# IT NZ
# Ttest_indResult(statistic=-0.81816062087957708, pvalue=0.41523037873783819)
# IT SE
# Ttest_indResult(statistic=0.094756818661859255, pvalue=0.9247054897973267)
# IT SG
# Ttest_indResult(statistic=0.95948345770897148, pvalue=0.33972557187412833)
# LU MX
# Ttest_indResult(statistic=-0.76636055071972853, pvalue=0.44511833868279449)
# LU NL
# Ttest_indResult(statistic=1.4408108673768532, pvalue=0.15255805398961444)
# LU NO
# Ttest_indResult(statistic=-0.97904410934588326, pvalue=0.32983016839310964)
# LU NZ
# Ttest_indResult(statistic=-0.19778581418768507, pvalue=0.84358443692098584)
# LU SE
# Ttest_indResult(statistic=0.78665082522080931, pvalue=0.43325817546730927)
# LU SG
# Ttest_indResult(statistic=1.6101215921780017, pvalue=0.11037368348943184)
# MX NL
# Ttest_indResult(statistic=2.0620328731084792, pvalue=0.041851107058358733)
# MX NO
# Ttest_indResult(statistic=-0.16765064976902133, pvalue=0.86721449632488268)
# MX NZ
# Ttest_indResult(statistic=0.51840817993572319, pvalue=0.60533025412572949)
# MX SE
# Ttest_indResult(statistic=1.5327999597792556, pvalue=0.12861414457929926)
# MX SG
# Ttest_indResult(statistic=2.299537687407156, pvalue=0.023641299499012416)
# NL NO
# Ttest_indResult(statistic=-2.3419172400103418, pvalue=0.021319223614568433)
# NL NZ
# Ttest_indResult(statistic=-1.5069370160150766, pvalue=0.13507671135547314)
# NL SE
# Ttest_indResult(statistic=-0.77209020128631733, pvalue=0.44199782991748993)
# NL SG
# Ttest_indResult(statistic=0.019046615688314075, pvalue=0.98484428860371009)
# NO NZ
# Ttest_indResult(statistic=0.70604872422664777, pvalue=0.48190409822426017)
# NO SE
# Ttest_indResult(statistic=1.8630426333851993, pvalue=0.065681969096658605)
# NO SG
# Ttest_indResult(statistic=2.6968454719653319, pvalue=0.0083405249764050959)
# NZ SE
# Ttest_indResult(statistic=0.92801923161927136, pvalue=0.35574946034137489)
# NZ SG
# Ttest_indResult(statistic=1.6835386483806589, pvalue=0.095554296386867868)
# SE SG
# Ttest_indResult(statistic=0.93023519711584512, pvalue=0.354683835774939)

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

tukey = pairwise_tukeyhsd(endog=active_pledged,
                         groups=active_country,
                         alpha=0.05)

tukey.plot_simultaneous()
plt.vlines(x=49.57,ymin=-0.5,ymax=4.5,color="red")

tukey.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
